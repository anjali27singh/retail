# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import load_dataset

data = pd.read_csv("/retail_sales_dataset.csv")
#tips dataset
tips = load_dataset("tips")

# %%
data.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
data.tail()
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
null_perc = round(100*(data.isnull().sum()/len(data.index)),2)

# %%
null_perc[null_perc>0]
# Out:
# Series([], dtype: float64)

# %%
data.nunique()
# Out:
# Transaction ID      1000
# Date                 345
# Customer ID         1000
# Gender                 2
# Age                   47
# Product Category       3
# Quantity               4
# Price per Unit         5
# Total Amount          18
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# Transaction ID      0.0
# Date                0.0
# Customer ID         0.0
# Gender              0.0
# Age                 0.0
# Product Category    0.0
# Quantity            0.0
# Price per Unit      0.0
# Total Amount        0.0
# dtype: float64

# %%
data = data.drop(['Transaction ID'], axis = 1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              1000 non-null   object
#  1   Customer ID       1000 non-null   object
#  2   Gender            1000 non-null   object
#  3   Age               1000 non-null   int64
#  4   Product Category  1000 non-null   object
#  5   Quantity          1000 non-null   int64
#  6   Price per Unit    1000 non-null   int64
#  7   Total Amount      1000 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 62.6+ KB

# %%
from datetime import date
date.today().year
data['Age']=date.today()
data.head()
# Out:
#          Date Customer ID  Gender         Age Product Category  Quantity  \
# 0  2023-11-24     CUST001    Male  2024-03-05           Beauty         3
# 1  2023-02-27     CUST002  Female  2024-03-05         Clothing         2
# 2  2023-01-13     CUST003    Male  2024-03-05      Electronics         1
# 3  2023-05-21     CUST004    Male  2024-03-05         Clothing         1
# 4  2023-05-06     CUST005    Male  2024-03-05           Beauty         2
#
#    Price per Unit  Total Amount
# 0              50           150
# 1             500          1000
# 2              30            30
# 3             500           500
# 4              50           100

# %%
data.describe().T
# Out:
#                  count     mean         std   min   25%    50%    75%     max
# Quantity        1000.0    2.514    1.132734   1.0   1.0    3.0    4.0     4.0
# Price per Unit  1000.0  179.890  189.681356  25.0  30.0   50.0  300.0   500.0
# Total Amount    1000.0  456.000  559.997632  25.0  60.0  135.0  900.0  2000.0

# %%
data.describe(include='all').T
# Out:
#                    count unique         top  freq    mean         std   min  \
# Date                1000    345  2023-05-16    11     NaN         NaN   NaN
# Customer ID         1000   1000     CUST001     1     NaN         NaN   NaN
# Gender              1000      2      Female   510     NaN         NaN   NaN
# Age                 1000      1  2024-03-05  1000     NaN         NaN   NaN
# Product Category    1000      3    Clothing   351     NaN         NaN   NaN
# Quantity          1000.0    NaN         NaN   NaN   2.514    1.132734   1.0
# Price per Unit    1000.0    NaN         NaN   NaN  179.89  189.681356  25.0
# Total Amount      1000.0    NaN         NaN   NaN   456.0  559.997632  25.0
#
#                    25%    50%    75%     max
# Date               NaN    NaN    NaN     NaN
# Customer ID        NaN    NaN    NaN     NaN
# Gender             NaN    NaN    NaN     NaN
# Age                NaN    NaN    NaN     NaN
# Product Category   NaN    NaN    NaN     NaN
# ...

# %%
cat_cols=data.select_dtypes(include=['object']).columns
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['Date', 'Customer ID', 'Gender', 'Age', 'Product Category'], dtype='object')
# Numerical Variables:
# ['Quantity', 'Price per Unit', 'Total Amount']

# %%
for col in num_cols:
    print(col)
    print('Skew :', round(data[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    data[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=data[col])
    plt.show()
# Out:
# Quantity
# Skew : -0.01
# Price per Unit
# Skew : 0.74
# Total Amount
# Skew : 1.38

# %%
plt.figure(figsize=(13,17))
sns.pairplot(data=data.drop(['Quantity','Price per Unit'],axis=1))
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
df_temperature = pd.read_csv('/retail_sales_dataset.csv', encoding='utf-8')
df_temperature.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
data.set_index('Any', inplace=True)
data.index.name = 'Amount'
data['Amount'] = df_temperature.mean(axis=1)
data = data[['average']]
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-25fb73b247bb> in <cell line: 1>()
# ----> 1 data.set_index('Any', inplace=True)
#       2 data.index.name = 'Amount'
#       3 # Yearly average air temperature - calculation
#       4 data['Amount'] = df_temperature.mean(axis=1)
#       5 # drop unwanted columns and resetting the datafreame
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# ...
